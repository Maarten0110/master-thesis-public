# %%
# !rm -r sample_data
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0, "/content/master-thesis-public/code")

# %%
# !rm -rf master-thesis-public
# !git clone https://github.com/Maarten0110/master-thesis-public.git

# %% [markdown]
# ### global settings

# %%
layer_width = 1000

# %% [markdown]
# ### [e05] the magnitude of the preactivations for one input

# %%
from run05 import paramaters as parameters_e05, run_experiment as run_experiment_e05

def Cw_scale_invariant(a_plus, a_min):
    A2 = ((a_plus ** 2) + (a_min ** 2)) / 2
    return 1 / A2

# scale-invariant universality class
jobs = [
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"}, input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"},   input_norm=1)},
]
run_experiment_e05(jobs, batch_size_on_GPU = 25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %%
from run05 import paramaters as parameters_e05, run_experiment as run_experiment_e05
from math import factorial as fac, sqrt

def Cw_K_star_zero(sigma_1):
    Cw0 = 1 / (sigma_1 ** 2)
    return Cw0 + 1 / layer_width * (2/3) * Cw0

def activation_dict_custom_polynomial(eps):
    c1 = 1
    c2 = 1 / fac(2)
    c3 = -0.75 / fac(3)
    c4 = -(3/8 + 8/5 * eps) / fac(4)
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly_eps={eps}"}

def activation_dict_custom_polynomial2(eps_a, eps_b):
    c1 = 1
    c2 = sqrt(4*eps_a) / fac(2)
    c3 = -4 * eps_a / fac(3)
    c4 = - (eps_b + 12 * (eps_a ** 2)) / (sqrt(4*eps_a) * fac(4))
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly2_eps1={eps_a}_eps2={eps_b}"}

# K* = 0 universality class
jobs = [
    # custom polynomials
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(    3, 0.01),   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 3),      input_norm=1)},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),  input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.5),   input_norm=1)},

    # tanh
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.5),  Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.5,  "file_base": "tanh_b=0.5"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(2),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 2,    "file_base": "tanh_b=2"},   input_norm=1)},

    # sin
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},   input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin"},   input_norm=1)},

    # shifted sigmoid
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1/4),  Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"}, input_norm=1)},
]
run_experiment_e05(jobs, batch_size_on_GPU = 25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %%
from run05 import paramaters as parameters_e05, run_experiment as run_experiment_e05
from math import sqrt

def input_norm_half_stable(K00, layer_width) -> float:
    return sqrt(K00 * layer_width)

# half stable universality class
jobs = [
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_0"}, input_norm=input_norm_half_stable(0.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_1"}, input_norm=input_norm_half_stable(1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_2"}, input_norm=input_norm_half_stable(14.32017362 / 2, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_3"}, input_norm=input_norm_half_stable(10, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_4"}, input_norm=input_norm_half_stable(14.32017362 * 0.99, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_5"}, input_norm=input_norm_half_stable(14.32017362 * 1,    layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_6"}, input_norm=input_norm_half_stable(14.32017362 * 1.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_7"}, input_norm=input_norm_half_stable(15, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98800468,  Cb=0.55514317, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_14_8"}, input_norm=input_norm_half_stable(20, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_0"}, input_norm=input_norm_half_stable(0.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_1"}, input_norm=input_norm_half_stable(1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_2"}, input_norm=input_norm_half_stable(14.32017362 / 2, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_3"}, input_norm=input_norm_half_stable(10, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_4"}, input_norm=input_norm_half_stable(14.32017362 * 0.99, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_5"}, input_norm=input_norm_half_stable(14.32017362 * 1,    layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_6"}, input_norm=input_norm_half_stable(14.32017362 * 1.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_7"}, input_norm=input_norm_half_stable(15, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "swish", "file_base": "swish_0_8"}, input_norm=input_norm_half_stable(20, layer_width))},
    
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_0"}, input_norm=input_norm_half_stable(0.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_1"}, input_norm=input_norm_half_stable(1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_2"}, input_norm=input_norm_half_stable(3.56155281281 / 2, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_3"}, input_norm=input_norm_half_stable(3.2, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_4"}, input_norm=input_norm_half_stable(3.56155281281 * 0.99, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_5"}, input_norm=input_norm_half_stable(3.56155281281 * 1,    layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_6"}, input_norm=input_norm_half_stable(3.56155281281 * 1.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_7"}, input_norm=input_norm_half_stable(4, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=1.98305826,  Cb=0.17292239, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_14_8"}, input_norm=input_norm_half_stable(6, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_0"}, input_norm=input_norm_half_stable(0.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_1"}, input_norm=input_norm_half_stable(1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_2"}, input_norm=input_norm_half_stable(3.56155281281 / 2, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_3"}, input_norm=input_norm_half_stable(3.2, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_4"}, input_norm=input_norm_half_stable(3.56155281281 * 0.99, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_5"}, input_norm=input_norm_half_stable(3.56155281281 * 1,    layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_6"}, input_norm=input_norm_half_stable(3.56155281281 * 1.01, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_7"}, input_norm=input_norm_half_stable(4, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=4,  Cb=0, Nw=10000, seed=0, activation={"name": "gelu", "file_base": "gelu_0_8"}, input_norm=input_norm_half_stable(6, layer_width))},
]
run_experiment_e05(jobs, batch_size_on_GPU = 25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %% [markdown]
# #### e05 but investigation of SI u-class decay

# %%
from run05 import paramaters as parameters_e05, run_experiment as run_experiment_e05

def Cw_scale_invariant(a_plus, a_min):
    A2 = ((a_plus ** 2) + (a_min ** 2)) / 2
    return 1 / A2

jobs = [
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw= 7500, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw= 5000, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw= 2500, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw= 1000, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},

    {"params": parameters_e05(L=100, n= 750, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
    {"params": parameters_e05(L=100, n= 500, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
    {"params": parameters_e05(L=100, n= 250, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
    {"params": parameters_e05(L=100, n= 100, Cw=Cw_scale_invariant(0, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, input_norm=1)},
]
run_experiment_e05(jobs, batch_size_on_GPU = 25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %% [markdown]
# #### e05 but with varying input magnitudes

# %%
from run05 import paramaters as parameters_e05, run_experiment as run_experiment_e05
from math import factorial as fac, sqrt


def K_to_input_norm(K, n):
    return sqrt(n*K)

def Cw_K_star_zero(sigma_1):
    Cw0 = 1 / (sigma_1 ** 2)
    return Cw0 + 1 / layer_width * (2/3) * Cw0

def activation_dict_custom_polynomial(eps):
    c1 = 1
    c2 = 1 / fac(2)
    c3 = -0.75 / fac(3)
    c4 = -(3/8 + 8/5 * eps) / fac(4)
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly_eps={eps}"}

def activation_dict_custom_polynomial2(eps_a, eps_b):
    c1 = 1
    c2 = sqrt(4*eps_a) / fac(2)
    c3 = -4 * eps_a / fac(3)
    c4 = - (eps_b + 12 * (eps_a ** 2)) / (sqrt(4*eps_a) * fac(4))
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly2_eps1={eps_a}_eps2={eps_b}"}

# K* = 0 universality class
jobs = [
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(0.1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(0.1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(0.1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(0.1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(0.1, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(0.1, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(0.5, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(0.5, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(0.5, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(0.5, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(0.5, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(0.5, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(1.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(1.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(1.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(1.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(1.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(1.0, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(2.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(2.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(2.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(2.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(2.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(2.0, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(5.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(5.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(5.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(5.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(5.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(5.0, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(10.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(10.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(10.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(10.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(10.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(10.0, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(20.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(20.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(20.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(20.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(20.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(20.0, layer_width))},

    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             input_norm=K_to_input_norm(50.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      input_norm=K_to_input_norm(50.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               input_norm=K_to_input_norm(50.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    input_norm=K_to_input_norm(50.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 input_norm=K_to_input_norm(50.0, layer_width))},
    {"params": parameters_e05(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      input_norm=K_to_input_norm(50.0, layer_width))},
]
run_experiment_e05(jobs, batch_size_on_GPU = 25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %% [markdown]
# ### [e06] the difference in magnitude of the preactivations for two inputs

# %%
from run06 import paramaters as parameters_e06, run_experiment as run_experiment_e06

def Cw_scale_invariant(a_plus, a_min):
    A2 = ((a_plus ** 2) + (a_min ** 2)) / 2
    return 1 / A2

jobs = [
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"}, midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"}, midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"}, midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, midpoint_norm=1, midpoint_deviaton=0.001)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"}, midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"}, midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"}, midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, midpoint_norm=1, midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"}, midpoint_norm=1, midpoint_deviaton=0.05)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, midpoint_norm=1, midpoint_deviaton=0.05)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"}, midpoint_norm=1, midpoint_deviaton=0.05)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"}, midpoint_norm=1, midpoint_deviaton=0.05)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, midpoint_norm=1, midpoint_deviaton=0.05)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, midpoint_norm=1, midpoint_deviaton=0.05)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"}, midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"}, midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"}, midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"}, midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, midpoint_norm=1, midpoint_deviaton=0.5)},
]
run_experiment_e06(jobs, batch_size_on_GPU=25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %%
from run06 import paramaters as parameters_e06, run_experiment as run_experiment_e06

from math import factorial as fac, sqrt

def Cw_K_star_zero(sigma_1):
    Cw0 = 1 / (sigma_1 ** 2)
    return Cw0 + 1 / layer_width * (2/3) * Cw0

def activation_dict_custom_polynomial(eps):
    c1 = 1
    c2 = 1 / fac(2)
    c3 = -0.75 / fac(3)
    c4 = -(3/8 + 8/5 * eps) / fac(4)
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly_eps={eps}"}

def activation_dict_custom_polynomial2(eps_a, eps_b):
    c1 = 1
    c2 = sqrt(4*eps_a) / fac(2)
    c3 = -4 * eps_a / fac(3)
    c4 = - (eps_b + 12 * (eps_a ** 2)) / (sqrt(4*eps_a) * fac(4))
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly2_eps1={eps_a}_eps2={eps_b}"}

# K* = 0 universality class
jobs = [
    # {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(    3, 0.01),                     midpoint_norm=1, midpoint_deviaton=0.001)},
    # {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 3),                        midpoint_norm=1, midpoint_deviaton=0.001)},
    # {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=1, midpoint_deviaton=0.001)},
    # {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.5),                              midpoint_norm=1, midpoint_deviaton=0.001)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=1, midpoint_deviaton=0.001)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     midpoint_norm=1, midpoint_deviaton=0.001)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=1, midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     midpoint_norm=1, midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=1, midpoint_deviaton=0.1)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    midpoint_norm=1, midpoint_deviaton=0.1)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=1, midpoint_deviaton=0.1)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      midpoint_norm=1, midpoint_deviaton=0.1)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         midpoint_norm=1, midpoint_deviaton=0.1)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=1, midpoint_deviaton=0.1)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     midpoint_norm=1, midpoint_deviaton=0.1)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=1, midpoint_deviaton=0.5)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     midpoint_norm=1, midpoint_deviaton=0.5)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=1, midpoint_deviaton=0.75)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    midpoint_norm=1, midpoint_deviaton=0.75)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=1, midpoint_deviaton=0.75)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      midpoint_norm=1, midpoint_deviaton=0.75)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         midpoint_norm=1, midpoint_deviaton=0.75)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=1, midpoint_deviaton=0.75)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     midpoint_norm=1, midpoint_deviaton=0.75)},
]
run_experiment_e06(jobs, batch_size_on_GPU=25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %% [markdown]
# #### e06 but with varying input magnitudes

# %%
from run06 import paramaters as parameters_e06, run_experiment as run_experiment_e06
from math import factorial as fac, sqrt


def K_to_input_norm(K, n):
    return sqrt(n*K)

def Cw_K_star_zero(sigma_1):
    Cw0 = 1 / (sigma_1 ** 2)
    return Cw0 + 1 / layer_width * (2/3) * Cw0

def activation_dict_custom_polynomial(eps):
    c1 = 1
    c2 = 1 / fac(2)
    c3 = -0.75 / fac(3)
    c4 = -(3/8 + 8/5 * eps) / fac(4)
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly_eps={eps}"}

def activation_dict_custom_polynomial2(eps_a, eps_b):
    c1 = 1
    c2 = sqrt(4*eps_a) / fac(2)
    c3 = -4 * eps_a / fac(3)
    c4 = - (eps_b + 12 * (eps_a ** 2)) / (sqrt(4*eps_a) * fac(4))
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly2_eps1={eps_a}_eps2={eps_b}"}

# K* = 0 universality class
jobs = [
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(0.1, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(0.1, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(0.1, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(0.1, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(0.1, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(0.1, layer_width), midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(0.5, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(0.5, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(0.5, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(0.5, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(0.5, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(0.5, layer_width), midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(1.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(1.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(1.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(1.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(1.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(1.0, layer_width), midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(2.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(2.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(2.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(2.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(2.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(2.0, layer_width), midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(5.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(5.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(5.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(5.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(5.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(5.0, layer_width), midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(10.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(10.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(10.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(10.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(10.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(10.0, layer_width), midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(20.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(20.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(20.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(20.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(20.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(20.0, layer_width), midpoint_deviaton=0.01)},

    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             midpoint_norm=K_to_input_norm(50.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      midpoint_norm=K_to_input_norm(50.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               midpoint_norm=K_to_input_norm(50.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    midpoint_norm=K_to_input_norm(50.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 midpoint_norm=K_to_input_norm(50.0, layer_width), midpoint_deviaton=0.01)},
    {"params": parameters_e06(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      midpoint_norm=K_to_input_norm(50.0, layer_width), midpoint_deviaton=0.01)},
]
run_experiment_e06(jobs, batch_size_on_GPU = 25, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %% [markdown]
# ### [e07] the magnitude of the difference of the preactivations for two inputs

# %%
from run07 import paramaters as parameters_e07, run_experiment as run_experiment_e07
from math import pi

def Cw_scale_invariant(a_plus, a_min):
    A2 = ((a_plus ** 2) + (a_min ** 2)) / 2
    return 1 / A2

jobs = [
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"},                                          inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"},                                              inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"},      inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"},  inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.5), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.5, "file_base": "leaky-relu4"}, inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.75), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.75, "file_base": "leaky-relu5"}, inputs_norm=1, inputs_angle=pi/256)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.9), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.9, "file_base": "leaky-relu6"}, inputs_norm=1, inputs_angle=pi/256)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"},                                          inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"},                                              inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"},      inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"},  inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.5), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.5, "file_base": "leaky-relu4"}, inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.75), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.75, "file_base": "leaky-relu5"}, inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.9), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.9, "file_base": "leaky-relu6"}, inputs_norm=1, inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"},                                          inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"},                                              inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"},      inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"},  inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.5), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.5, "file_base": "leaky-relu4"}, inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.75), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.75, "file_base": "leaky-relu5"}, inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.9), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.9, "file_base": "leaky-relu6"}, inputs_norm=1, inputs_angle=pi/4)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"},                                          inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"},                                              inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"},      inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"},  inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.5), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.5, "file_base": "leaky-relu4"}, inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.75), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.75, "file_base": "leaky-relu5"}, inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.9), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.9, "file_base": "leaky-relu6"}, inputs_norm=1, inputs_angle=pi/2)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "linear", "file_base": "linear"},                                          inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0),   Cb=None, Nw=10000, seed=0, activation={"name": "relu", "file_base": "relu"},                                              inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 1),   Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": -1, "file_base": "s-i-abs"},      inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.1), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.1, "file_base": "leaky-relu"},  inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.4), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.4, "file_base": "leaky-relu2"}, inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.95), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.95, "file_base": "leaky-relu3"}, inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.5), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.5, "file_base": "leaky-relu4"}, inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.75), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.75, "file_base": "leaky-relu5"}, inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_scale_invariant(1, 0.9), Cb=None, Nw=10000, seed=0, activation={"name": "scale-invariant", "a_plus": 1, "a_min": 0.9, "file_base": "leaky-relu6"}, inputs_norm=1, inputs_angle=pi)},
]

run_experiment_e07(jobs, batch_size_on_GPU=20, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %%
from run07 import paramaters as parameters_e07, run_experiment as run_experiment_e07

from math import factorial as fac, sqrt

def Cw_K_star_zero(sigma_1):
    Cw0 = 1 / (sigma_1 ** 2)
    return Cw0 + 1 / layer_width * (2/3) * Cw0

def activation_dict_custom_polynomial(eps):
    c1 = 1
    c2 = 1 / fac(2)
    c3 = -0.75 / fac(3)
    c4 = -(3/8 + 8/5 * eps) / fac(4)
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly_eps={eps}"}

def activation_dict_custom_polynomial2(eps_a, eps_b):
    c1 = 1
    c2 = sqrt(4*eps_a) / fac(2)
    c3 = -4 * eps_a / fac(3)
    c4 = - (eps_b + 12 * (eps_a ** 2)) / (sqrt(4*eps_a) * fac(4))
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly2_eps1={eps_a}_eps2={eps_b}"}

# K* = 0 universality class
jobs = [
    # custom polynomials
    # {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),   inputs_norm=1, inputs_angle=pi/256)},
    # {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(    3, 0.01),   inputs_norm=1, inputs_angle=pi/256)},
    # {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 3),      inputs_norm=1, inputs_angle=pi/256)},   
    # {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),           inputs_norm=1, inputs_angle=pi/256)},
    # {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1), Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.5),            inputs_norm=1, inputs_angle=pi/256)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     inputs_norm=1, inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=1, inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     inputs_norm=1, inputs_angle=pi/4)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=1, inputs_angle=pi/4)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     inputs_norm=1, inputs_angle=pi/2)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=1, inputs_angle=pi/2)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "file_base": "tanh_b=0.05", "b": 0.05},    inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "file_base": "sin_b=0.05", "b": 0.05},      inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.25), Cb=None, Nw=10000, seed=0, activation={"name": "sigmoid-shifted", "file_base": "sigmoid-shifted"},         inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2( 0.01, 0.01),                     inputs_norm=1, inputs_angle=pi)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=1, inputs_angle=pi)},
]

run_experiment_e07(jobs, batch_size_on_GPU=20, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %% [markdown]
# #### e07 but with varying input magnitudes

# %%
from run07 import paramaters as parameters_e07, run_experiment as run_experiment_e07
from math import factorial as fac, sqrt, pi


def K_to_input_norm(K, n):
    return sqrt(n*K)

def Cw_K_star_zero(sigma_1):
    Cw0 = 1 / (sigma_1 ** 2)
    return Cw0 + 1 / layer_width * (2/3) * Cw0

def activation_dict_custom_polynomial(eps):
    c1 = 1
    c2 = 1 / fac(2)
    c3 = -0.75 / fac(3)
    c4 = -(3/8 + 8/5 * eps) / fac(4)
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly_eps={eps}"}

def activation_dict_custom_polynomial2(eps_a, eps_b):
    c1 = 1
    c2 = sqrt(4*eps_a) / fac(2)
    c3 = -4 * eps_a / fac(3)
    c4 = - (eps_b + 12 * (eps_a ** 2)) / (sqrt(4*eps_a) * fac(4))
    return {"name": "polynomial-degree-4", "c1": c1, "c2": c2, "c3": c3, "c4": c4, "file_base": f"poly2_eps1={eps_a}_eps2={eps_b}"}

# K* = 0 universality class
jobs = [
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(0.1, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(0.1, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(0.1, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(0.1, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(0.1, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(0.1, layer_width), inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(0.5, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(0.5, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(0.5, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(0.5, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(0.5, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(0.5, layer_width), inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(1.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(1.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(1.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(1.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(1.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(1.0, layer_width), inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(2.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(2.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(2.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(2.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(2.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(2.0, layer_width), inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(5.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(5.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(5.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(5.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(5.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(5.0, layer_width), inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(10.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(10.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(10.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(10.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(10.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(10.0, layer_width), inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(20.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(20.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(20.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(20.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(20.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(20.0, layer_width), inputs_angle=pi/16)},

    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial(0.01),                             inputs_norm=K_to_input_norm(50.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation=activation_dict_custom_polynomial2(0.01, 0.01),                      inputs_norm=K_to_input_norm(50.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "tanh", "file_base": "tanh"},                               inputs_norm=K_to_input_norm(50.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "tanh-modified", "b": 0.05, "file_base": "tanh_b=0.05"},    inputs_norm=K_to_input_norm(50.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(1),    Cb=None, Nw=10000, seed=0, activation={"name": "sin", "file_base": "sin"},                                 inputs_norm=K_to_input_norm(50.0, layer_width), inputs_angle=pi/16)},
    {"params": parameters_e07(L=100, n=layer_width, Cw=Cw_K_star_zero(0.05), Cb=None, Nw=10000, seed=0, activation={"name": "sin-modified", "b": 0.05, "file_base": "sin_b=0.05"},      inputs_norm=K_to_input_norm(50.0, layer_width), inputs_angle=pi/16)},
]
run_experiment_e07(jobs, batch_size_on_GPU = 20, save_raw_data_to_drive = False, remove_raw_data_after_analaysis_step = True)

# %% [markdown]
# ### Unmount Google Drive

# %%
drive.flush_and_unmount()
